# %% [markdown]
#  ## Extraction of Table Formats, such as Bank Statements, into Structured Formats
#
#  #### Overview:
#  - Develop a system to extract structured information from documents like bank statements that contain table based formats. The extracted information should include personal details (e.g., name, bank) and financial transactions, organised into a key value structure for personal details and table formats for transactions. The output should be saved in formats like XLSX or CSV for further analysis and processing.
#
#  #### Objective:
#  - The system should extract personal details (e.g., name, bank name) from the top of the bank statement in a key value format and the transaction data in table format. The extracted data should then be saved in table formats like CSV or XLSX for ease of use in financial analysis or reporting systems.
#
#  #### Data:
#  - Various Bank statements or similar financial documents containing tabular data and personal details.
#
#  #### Requirements:
#  ##### Input:
#  - Information Scanned or image based bank statements containing personal details at the top and tabular transaction data below.
#
#  ##### Output:
#  - Personal details in key value format (e.g., "Name: John Doe", "Bank: XYZ").
#  - Transaction details extracted in a tabular format and saved as XLSX, CSV, or JSON.

# %%
# Install PaddleOCR package
! pip install paddlepaddle paddleocr
# Out:
# Requirement already satisfied: paddlepaddle in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (2.6.2)
# Requirement already satisfied: paddleocr in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (2.8.1)
# Requirement already satisfied: httpx in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddlepaddle) (0.27.2)
# Requirement already satisfied: numpy>=1.13 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddlepaddle) (1.23.5)
# Requirement already satisfied: Pillow in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddlepaddle) (10.4.0)
# Requirement already satisfied: decorator in c:\users\augus\appdata\roaming\python\python38\site-packages (from paddlepaddle) (5.0.9)
# Requirement already satisfied: astor in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: protobuf<=3.20.2,>=3.1.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddlepaddle) (3.20.2)
# Requirement already satisfied: shapely in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (2.0.6)
# Requirement already satisfied: scikit-image in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (0.21.0)
# Requirement already satisfied: imgaug in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (1.3.0.post5)
# Requirement already satisfied: lmdb in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (4.66.5)
# Requirement already satisfied: rapidfuzz in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (3.9.7)
# Requirement already satisfied: opencv-python in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (4.10.0.84)
# Requirement already satisfied: cython in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (3.0.11)
# Requirement already satisfied: pyyaml in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: python-docx in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (4.53.1)
# Requirement already satisfied: fire>=0.3.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (0.6.0)
# Requirement already satisfied: requests in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from paddleocr) (2.32.3)
# Requirement already satisfied: six in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from fire>=0.3.0->paddleocr) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from beautifulsoup4->paddleocr) (2.6)
# Requirement already satisfied: anyio in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from httpx->paddlepaddle) (4.5.0)
# Requirement already satisfied: certifi in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from httpx->paddlepaddle) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from httpx->paddlepaddle) (1.0.5)
# Requirement already satisfied: idna in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from httpx->paddlepaddle) (3.10)
# Requirement already satisfied: sniffio in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: scipy in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from imgaug->paddleocr) (1.10.1)
# Requirement already satisfied: matplotlib in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from imgaug->paddleocr) (3.7.5)
# Requirement already satisfied: imageio in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from imgaug->paddleocr) (2.35.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from scikit-image->paddleocr) (3.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from scikit-image->paddleocr) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from scikit-image->paddleocr) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from scikit-image->paddleocr) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from python-docx->paddleocr) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from python-docx->paddleocr) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from requests->paddleocr) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from requests->paddleocr) (2.2.3)
# Requirement already satisfied: colorama in c:\users\augus\appdata\roaming\python\python38\site-packages (from tqdm->paddleocr) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from packaging>=21->scikit-image->paddleocr) (3.1.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from anyio->httpx->paddlepaddle) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\augus\anaconda3\envs\testocr\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug->paddleocr) (3.20.2)

# %% [markdown]
# Import the Libraries

# %%
import os
import re
import json
import pandas as pd
from paddleocr import PaddleOCR

# %% [markdown]
# File Path of Input and Output Directories

# %%
image_path = r'Input_Dir\Extraction_Table_Formats\sample_table_format.png'  # Change this to your image path
output_path = r'Output_Dir\Extraction_table_format'   # Change this to your desired output directory
# Create the output directory if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# %%
# Initialize PaddleOCR model
ocr = PaddleOCR(use_angle_cls=True, lang='en')

# Perform OCR on the image
ocr_result = ocr.ocr(image_path, cls=True)

# Extracted text result
extracted_text = []
for line in ocr_result[0]:
    extracted_text.append(line[1][0])

# Combine the extracted lines into a single text block
text = '\n'.join(extracted_text)
print(text)
# Out:
# [2024/09/25 17:58:24] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\augus/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\augus/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='c:\\Users\\augus\\anaconda3\\envs\\testocr\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\augus/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', recovery=False, return_word_box=False, save_crop_res=False, save_log_path='./log_output/', savefile=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mlu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [2024/09/25 17:58:27] ppocr DEBUG: dt_boxes num : 132, elapsed : 0.9109902381896973
# [2024/09/25 17:58:28] ppocr DEBUG: cls num  : 132, elapsed : 0.46970033645629883
# [2024/09/25 17:58:41] ppocr DEBUG: rec_res num  : 132, elapsed : 13.590295314788818
# SBI
# Account Name
# Mrs.BADDU
# Address
# V/P KALWABADA
# TEH-MAKRANA
# MAKRANA NAGAUR-341505
# Nagaur
# Date
# 4 Nov 2019
# Account Number
# :00000061068722344
# Account Description
# :REGULAR SB CHQ-INDIVIDUALS URAL-INR
# Branch
# MAKRANA
# Drawing Power
# 0.00
# Interest Rate(% p.a.)
# 3.25
# MOD Balance
# 0.00
# CIF No.
# 71104584150
# IFS Code
# SBIN0031113
# MICR Code
# 341002005
# Nomination Registered
# Balance as on 1 Sep 20192.994.76
# Account Statement from 1 Sep 2019 to 4 Nov2019
# Txn Date
# Value
# Description
# Ref No./Cheque
# Date
# Debit
# Credit
# Balance
# No.
# 1Sep 2019
# 1 Sep 2019 BY TRANSFER-INB
# MAB00033207679
# IMPS924416044700/97720435
# 5,000.00
# 7,994.76
# 13/XX2811/IMPSTxn-
# MAB00033207679
# 8
# 8
# 1 Sep2019
# 1 Sep 2019BY TRANSFER-INB
# MAC00033202020
# 2,000.00
# 9,994.76
# 13/XX2811/IMPS Txn-
# IMPS924416044725/97720435
# MAC00033202020
# 6
# 2 Sep2019
# 2 Sep 2019BY TRANSFER-
# TRANSFER
# NEFT*RBISOGORJEP'RBI246
# FROM
# 23,850.00
# 33,844.76
# 1906242380TREASURY
# 3199417044302
# OFFICE
# 6 Sep 20196 Sep 2019by deblt card-OTHPG
# 924901104796ONE97
# 2,000.00
# 31.844.76
# COMMUNICATIONS LNOIDA
# 6Sep2019
# 6 Sep 2019 by debit card-OTHPG
# 2,000.00
# 924901105800ONE97
# 29,844.76
# COMMUNICATIONS LNOIDA
# 6Sep2019
# 6 Sep 2019by deblt card-OTHPG
# 924902107893ONE97
# 2,000.00
# 27,844.76
# COMMUNICATIONS LNOIDA-
# 6 Sep 2019
# 6 Sep 2019 by debit card-OTHPG
# 924902129961ONE97
# 2,000.00
# 25,844.76
# COMMUNICATIONS LNOIDA
# 6Sep2019
# 2,000.00
# 23,844.76
# 924902133080ONE97
# COMMUNICATIONS LNOIDA-
# 6 Sep 20196 Sep 2019by debit card-SBIPG
# QT7949528859EMITRA
# 110.00
# 23,734.76
# MUMBAI-
# 9Sep2019
# 9 Sep 2019BY TRANSFER-INB
# MAB00033677292
# 340.00
# 24,074.76
# IMPS925219679279/82337779
# 68/XX7968/-
# MAB00033677292
# 12Sep
# 2019
# 12 SepATM WDL-ATM CASH4070
# 4,000.00
# 2019 BLA ATM
# PHULERA
# 20,074.76
# 21 Sep
# 21 Sep
# BY.TRANSFER
# TRANSFER
# 15,000.00
# 35,074.76
# 2019
# 2019 UPI/CR/926435090102/SUNIL
# B/SBIN/8233777968/NA-
# 5099195162098
# FROM

# %%
personal_details = {}

# Use regex to extract fields like Account Name, Account Number, Branch, etc.
patterns = {
    'Account Name': r"Account Name\s*(.*)",
    'Account Number': r"Account Number\s*:\s*(\d+)",
    'Account Description': r"Account Description\s*:\s*(.*)",
    'Branch': r"Branch\s*(.*)",
    'CIF No.': r"CIF No.\s*(\d+)",
    'IFS Code': r"IFS Code\s*(\w+)",
    'MICR Code': r"MICR Code\s*(\d+)",
    'Interest Rate': r"Interest Rate\(% p.a.\)\s*(\d+\.\d+)",
    'Drawing Power': r"Drawing Power\s*([0-9,.]+)",
    'MOD Balance': r"MOD Balance\s*([0-9,.]+)"
}

for key, pattern in patterns.items():
    match = re.search(pattern, text)
    if match:
        personal_details[key] = match.group(1).strip()

print(personal_details)
# Out:
# {'Account Name': 'Mrs.BADDU', 'Account Number': '00000061068722344', 'Account Description': 'REGULAR SB CHQ-INDIVIDUALS URAL-INR', 'Branch': 'MAKRANA', 'CIF No.': '71104584150', 'IFS Code': 'SBIN0031113', 'MICR Code': '341002005', 'Interest Rate': '3.25', 'Drawing Power': '0.00', 'MOD Balance': '0.00'}

# %%
# Split the data into lines
lines = text.strip().split('\n')

transactions = []
current_transaction = {}
previous_date = None

for line in lines:
    line = line.strip()
    
    # Check if the line is a valid date
    date_match = re.match(r'\d{1,2}\s?[A-Za-z]{3}\s?\d{4}|\d{1,2}[A-Za-z]{3}\d{4}', line)
    
    if date_match:
        current_date = date_match.group(0)

        # If there's a previous date, finalize the current transaction
        if previous_date and current_transaction:
            current_transaction['Transaction Date'] = previous_date
            current_transaction['Value Date'] = previous_date  # Ensure both dates are the same
            transactions.append(current_transaction)  # Save the current transaction
            current_transaction = {}  # Reset for the next transaction

        # Always update the current date
        previous_date = current_date  # Update the previous date
    
    elif re.match(r'^\d{1,3}(?:,\d{3})*(?:\.\d{2})?$', line):
        # Only process lines that match the float format
        amount = float(line.replace(',', ''))  # Remove commas and convert to float
        if 'Transaction Amount' not in current_transaction:  # Create Amount column
            current_transaction['Transaction Amount'] = amount
        else:
            # Set the balance only if the line is a valid numeric format
            balance = float(line.replace(',', ''))  # Convert balance to float
            if balance > amount:  # Ensure balance is always higher than amount
                current_transaction['Balance'] = balance
            else:
                # If the balance is not higher, retain the previously assigned balance
                current_transaction['Balance'] = current_transaction.get('Balance', balance)

# Finalizing the last transaction
if current_transaction:
    current_transaction['Transaction Date'] = previous_date
    current_transaction['Value Date'] = previous_date  # Ensure both dates are the same
    transactions.append(current_transaction)

# Convert transactions to DataFrame for easier manipulation
df_transactions = pd.DataFrame(transactions)

# Select and reorder columns
df_transactions = df_transactions[['Transaction Date', 'Value Date', 'Transaction Amount', 'Balance']]

# Format Amount and Balance to two decimal places
df_transactions['Transaction Amount'] = df_transactions['Transaction Amount'].map('{:.2f}'.format)
df_transactions['Balance'] = df_transactions['Balance'].map('{:.2f}'.format)

# Remove rows with '0.00', NaN, 'nan', and 'Nan'
df_transactions = df_transactions[~df_transactions['Transaction Amount'].isin(['0.00', 'nan', 'NaN'])]
df_transactions = df_transactions[~df_transactions['Balance'].isin(['0.00', 'nan', 'NaN'])]
df_transactions = df_transactions.dropna(subset=['Transaction Amount', 'Balance'])  # Drop rows with NaN values
print(df_transactions)
# Out:
#    Transaction Date  Value Date Transaction Amount   Balance
# 1        1 Sep 2019  1 Sep 2019            5000.00   7994.76
# 2        1 Sep 2019  1 Sep 2019            2000.00   9994.76
# 3        2 Sep 2019  2 Sep 2019           23850.00  33844.76
# 5        6 Sep 2019  6 Sep 2019            2000.00  29844.76
# 6        6 Sep 2019  6 Sep 2019            2000.00  27844.76
# 7        6 Sep 2019  6 Sep 2019            2000.00  25844.76
# 8          6Sep2019    6Sep2019            2000.00  23844.76
# 9        6 Sep 2019  6 Sep 2019             110.00  23734.76
# 10       9 Sep 2019  9 Sep 2019             340.00  24074.76

# %% [markdown]
# Save the Files in JSON, xlsx and CSV.

# %%
# Save personal details as JSON
personal_details_file_path = os.path.join(output_path, 'personal_details.json')
with open(personal_details_file_path, 'w') as json_file:
    json.dump(personal_details, json_file, indent=4)

# Save personal details as CSV
personal_details_df = pd.DataFrame.from_dict(personal_details, orient='index', columns=['Value'])
personal_details_df.index.name = 'Details'  # Rename the index to "Details"
personal_details_df.reset_index(inplace=True)  # Reset the index to make it a column
personal_details_csv_path = os.path.join(output_path, 'personal_details.csv')
personal_details_df.to_csv(personal_details_csv_path, index=False)

# Save personal details as XLSX
personal_details_xlsx_path = os.path.join(output_path, 'personal_details.xlsx')
personal_details_df.to_excel(personal_details_xlsx_path)

# Save transactions as JSON
transactions_path_json = os.path.join(output_path, 'transactions.json')
with open(transactions_path_json, 'w') as json_file:
    # Filter out transactions where both Transaction Amount and Balance are greater than 0
    valid_transactions = df_transactions[
        (df_transactions['Transaction Amount'].astype(float) > 0) & 
        (df_transactions['Balance'].astype(float) > 0)
    ]
    json.dump(valid_transactions.to_dict(orient='records'), json_file, indent=4)


# Save transactions as CSV
transactions_csv_path = os.path.join(output_path, 'transactions.csv')
df_transactions.to_csv(transactions_csv_path, index=False)

# Save transactions as XLSX
transactions_xlsx_path = os.path.join(output_path, 'transactions.xlsx')
df_transactions.to_excel(transactions_xlsx_path, index=False)

print("Files saved successfully!")
# Out:
# Files saved successfully!
